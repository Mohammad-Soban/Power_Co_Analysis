# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

# %matplotlib inline

# %% [markdown]
# ### <center> Basic Understanding Of The Data </center>

# %% [markdown]
# To Load `client_data.csv` and `price_data.csv` files into separte dataframes

# %%
df_client = pd.read_csv('Data/client_data.csv')
df_price = pd.read_csv('Data/price_data.csv')

# %% [markdown]
# Checking the Dataframe of `client Data`

# %%
print("CLIENT DATA HEADER")
df_client.head(3)
# Out:
# CLIENT DATA HEADER
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# 0      2015-11-01   2015-06-23               0.00  ...        t       0.0
# 1      2009-08-21   2015-08-31             189.95  ...        f       0.0
# 2      2010-04-16   2015-04-17              47.96  ...        f       0.0
#
#    margin_gross_pow_ele  margin_net_pow_ele  nb_prod_act  net_margin  \
# ...

# %% [markdown]
# Checking the Dataframe of `Price Data`

# %%
print("PRICE DATA HEADER")
df_price.head(3)
# Out:
# PRICE DATA HEADER
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0

# %% [markdown]
# The Basic Information Of the Dataframe of `client Data` and `Price Data`

# %%
# Checking the columns and their corresponding datatypes in both the dataset
print("CLIENT DATA INFORMATION")
df_client.info()
# Out:
# CLIENT DATA INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
# ...

# %%
print("PRICE DATA INFORMATION")
df_price.info()
# Out:
# PRICE DATA INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  object
#  1   price_date          193002 non-null  object
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.8+ MB

# %% [markdown]
# Statistical Summary Of the Dataframe of `client Data` and `Price Data`

# %%
# Checking the information of the dataset (Statistical Summary)
df_client.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %%
df_price.describe()
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# 25%             40.728885        0.000000            0.000000
# ...

# %% [markdown]
# Giving the Shape of the Dataframe of `client Data` and `Price Data`

# %%
# TO get the shape of the dataset
df_client.shape
# Out:
# (14606, 26)

# %%
# To get the shape of the price dataset
df_price.shape
# Out:
# (193002, 8)

# %% [markdown]
# ### <center> Data Cleaning </center>

# %% [markdown]
# Finding the missing values in the Dataframe of `client Data`

# %%
# Finding If there are any missing values in the dataset
df_client.isnull().sum()

# The asnwer is no missing values in the dataset
# Out:
# id                                0
# channel_sales                     0
# cons_12m                          0
# cons_gas_12m                      0
# cons_last_month                   0
# date_activ                        0
# date_end                          0
# date_modif_prod                   0
# date_renewal                      0
# forecast_cons_12m                 0
# forecast_cons_year                0
# forecast_discount_energy          0
# forecast_meter_rent_12m           0
# forecast_price_energy_off_peak    0
# forecast_price_energy_peak        0
# forecast_price_pow_off_peak       0
# has_gas                           0
# imp_cons                          0
# margin_gross_pow_ele              0
# margin_net_pow_ele                0
# nb_prod_act                       0
# net_margin                        0
# num_years_antig                   0
# origin_up                         0
# pow_max                           0
# churn                             0
# ...

# %% [markdown]
# Converting the data in the client dataframe to the correct data type

# %%
# For data_activ column
df_client['date_activ'] = pd.to_datetime(df_client['date_activ'])

# For date_end
df_client['date_end'] = pd.to_datetime(df_client['date_end'])

# For date_modif_prod
df_client['date_modif_prod'] = pd.to_datetime(df_client['date_modif_prod'])

# For date_renewal
df_client['date_renewal'] = pd.to_datetime(df_client['date_renewal'])

# Checking the datatypes of the columns
df_client.dtypes
# Out:
# id                                        object
# channel_sales                             object
# cons_12m                                   int64
# cons_gas_12m                               int64
# cons_last_month                            int64
# date_activ                        datetime64[ns]
# date_end                          datetime64[ns]
# date_modif_prod                   datetime64[ns]
# date_renewal                      datetime64[ns]
# forecast_cons_12m                        float64
# forecast_cons_year                         int64
# forecast_discount_energy                 float64
# forecast_meter_rent_12m                  float64
# forecast_price_energy_off_peak           float64
# forecast_price_energy_peak               float64
# forecast_price_pow_off_peak              float64
# has_gas                                   object
# imp_cons                                 float64
# margin_gross_pow_ele                     float64
# ...

# %% [markdown]
# Converting the categorical column `has_gas` to a numerical one consisting of 0s and 1s

# %%
# Converting all the t values in dataset to 1 and f values to 0 in the has_gas column
df_client['has_gas'] = df_client['has_gas'].map({'t': 1, 'f': 0})

df_client['has_gas'].value_counts()
# Out:
# has_gas
# 0    11955
# 1     2651
# Name: count, dtype: int64

# %% [markdown]
# Separating the numerical and categorical columns in the Dataframe of `client Data`

# %%
# Finding the numerical data columns in a separate dataframe
df_num = df_client.select_dtypes(include = ['int64', 'float64'])

# Finding the categorical data columns in a separate dataframe
df_cat = df_client.select_dtypes(include = ['object'])

# %% [markdown]
# Finding the outliers in the Dataframe of `client Data`

# %%
df_num['churn'].value_counts()
# Out:
# churn
# 0    13187
# 1     1419
# Name: count, dtype: int64

# %%
# Finding the churn rate
churn_rate = df_num['churn'].value_counts()[1]/len(df_num)
print(f"The churn rate is {churn_rate}")

# Finding the churn rate in percentage
churn_rate_percentage = churn_rate*100
print(f"The churn rate in percentage is {churn_rate_percentage}")
# Out:
# The churn rate is 0.09715185540188963
# The churn rate in percentage is 9.715185540188962

# %%
df_num.columns
# Out:
# Index(['cons_12m', 'cons_gas_12m', 'cons_last_month', 'forecast_cons_12m',
#        'forecast_cons_year', 'forecast_discount_energy',
#        'forecast_meter_rent_12m', 'forecast_price_energy_off_peak',
#        'forecast_price_energy_peak', 'forecast_price_pow_off_peak', 'has_gas',
#        'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act',
#        'net_margin', 'num_years_antig', 'pow_max', 'churn'],
#       dtype='object')

# %% [markdown]
# #### <center> Visualizations </center>

# %% [markdown]
# Outliers in the Dataframe of `client Data` using Boxplot

# %%
# Finding the outliers in the dataset using the box plots
plt.figure(figsize = (15, 10))

plt.subplot(4, 4, 1)
sns.boxplot(data = df_num['cons_12m'], orient = 'h')
plt.title('cons_12m')

plt.subplot(4, 4, 2)
sns.boxplot(data = df_num['cons_gas_12m'], orient = 'h')
plt.title('cons_gas_12m')

plt.subplot(4, 4, 3)
sns.boxplot(data = df_num['cons_last_month'], orient = 'h')
plt.title('cons_last_month')

plt.subplot(4, 4, 4)
sns.boxplot(data = df_num['forecast_cons_12m'], orient = 'h')
plt.title('forecast_cons_12m')

plt.subplot(4, 4, 5)
sns.boxplot(data = df_num['forecast_cons_year'], orient = 'h')
plt.title('forecast_cons_year')

plt.subplot(4, 4, 6)
sns.boxplot(data = df_num['forecast_meter_rent_12m'], orient = 'h')
plt.title('forecast_meter_rent_12m')

plt.subplot(4, 4, 7)
sns.boxplot(data = df_num['imp_cons'], orient = 'h')
plt.title('imp_cons')

plt.subplot(4, 4, 8)
sns.boxplot(data = df_num['margin_gross_pow_ele'], orient = 'h')
plt.title('margin_gross_pow_ele')

plt.subplot(4, 4, 9)
sns.boxplot(data = df_num['margin_net_pow_ele'], orient = 'h')
plt.title('margin_net_pow_ele')

plt.subplot(4, 4, 10)
sns.boxplot(data = df_num['forecast_discount_energy'], orient = 'h')
plt.title('forecast_discount_energy')

plt.subplot(4, 4, 11)
sns.boxplot(data = df_num['forecast_price_energy_off_peak'], orient = 'h')
plt.title('forecast_price_energy_off_peak')

plt.subplot(4, 4, 12)
sns.boxplot(data = df_num['forecast_price_energy_peak'], orient = 'h')
plt.title('forecast_price_energy_peak')

plt.subplot(4, 4, 13)
sns.boxplot(data = df_num['forecast_price_pow_off_peak'], orient = 'h')
plt.title('forecast_price_pow_off_peak')

plt.subplot(4, 4, 14)
sns.boxplot(data = df_num['pow_max'], orient = 'h')
plt.title('forecast_price_pow_peak')

plt.subplot(4, 4, 15)
sns.boxplot(data = df_num['nb_prod_act'], orient = 'h')
plt.title('nb_prod_act')

plt.subplot(4, 4, 16)
sns.boxplot(data = df_num['net_margin'], orient = 'h')
plt.title('net_margin')

plt.show()

# %% [markdown]
# Removing the outliers in the Dataframe of `client Data`

# %%
# To find the upper bound and lower bound of the distribution using inter-quantile range
def iqr_range(arr):
    q1 = np.quantile(arr,0.25)
    q3 = np.quantile(arr,0.75)
    iqr = q3-q1
    return q1-(iqr*1.5),q3+(iqr*1.5)

def outlier_removal(df,column,drop_percentage=0.05):
    
    actual_rows = df.shape[0]
    lower_bound,upper_bound = iqr_range(df[column].values)
    outliers = df[ (df[column]<lower_bound) | (df[column]>upper_bound) ]
    print('Total No of rows in actual dataframe : ',actual_rows,'\nTotal No of rows in outliers : ',outliers.shape[0])
    if outliers.shape[0] <= round(actual_rows*drop_percentage):
        df.drop(outliers.index,inplace=True)
    
    return df

# %%
def plot_stacked_bars(dataframe, title_, size_=(18, 10), rot_=0, legend_="upper right"):
    """
    Plot stacked bars with annotations
    """
    ax = dataframe.plot(
        kind="bar",
        stacked=True,
        figsize=size_,
        rot=rot_,
        title=title_
    )

    # Annotate bars
    annotate_stacked_bars(ax, textsize=14)
    # Rename legend
    plt.legend(["Retention", "Churn"], loc=legend_)
    # Labels
    plt.ylabel("Company base (%)")
    plt.show()

def annotate_stacked_bars(ax, pad=0.99, colour="white", textsize=13):
    """
    Add value annotations to the bars
    """

    # Iterate over the plotted rectanges/bars
    for p in ax.patches:
        
        # Calculate annotation
        value = str(round(p.get_height(),1))
        # If value is 0 do not annotate
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad),
            color=colour,
            size=textsize
        )

def plot_distribution(dataframe, column, ax, bins_=50):
    """
    Plot variable distirbution in a stacked histogram of churned or retained company
    """
    # Create a temporal dataframe with the data to be plot
    temp = pd.DataFrame({"Retention": dataframe[dataframe["churn"]==0][column],
    "Churn":dataframe[dataframe["churn"]==1][column]})
    # Plot the histogram
    temp[["Retention","Churn"]].plot(kind='hist', bins=bins_, ax=ax, stacked=True)
    # X-axis label
    ax.set_xlabel(column)
    # Change the x-axis to plain style
    ax.ticklabel_format(style='plain', axis='x')

# %%
churn = df_client[['id', 'churn']]
churn.columns = ['Companies', 'churn']
churn_total = churn.groupby(churn['churn']).count()
churn_percentage = churn_total / churn_total.sum() * 100
plot_stacked_bars(churn_percentage.transpose(), "Churning status", (5, 5), legend_="lower right")

# %%
# Create a dataframe and find all the unique values in every column, the dataframe should be of the form: column_name, [unique_values]
unique_values = pd.DataFrame([(col, df_client[col].nunique()) for col in df_client.columns], columns=['Column Name', 'Unique Values']).sort_values(by='Unique Values')

unique_values
# Out:
#                        Column Name  Unique Values
# 25                           churn              2
# 16                         has_gas              2
# 23                       origin_up              6
# 1                    channel_sales              8
# 20                     nb_prod_act             10
# 11        forecast_discount_energy             12
# 22                 num_years_antig             13
# 15     forecast_price_pow_off_peak             41
# 14      forecast_price_energy_peak            329
# 6                         date_end            368
# 8                     date_renewal            386
# 13  forecast_price_energy_off_peak            516
# 24                         pow_max            698
# 5                       date_activ           1796
# 3                     cons_gas_12m           2112
# 7                  date_modif_prod           2129
# 19              margin_net_pow_ele           2391
# 18            margin_gross_pow_ele           2391
# ...

# %%
# Plotting the heatmap of the numerical columns to find the correlation between the columns
plt.figure(figsize=(15, 10))

sns.heatmap(df_num.corr(), annot=True, fmt='.2f', cmap='coolwarm', linewidths=2)
# Out:
# <Axes: >
